# %%
import numpy as np

# %%
np.random.normal(loc=1.2,scale=0.5,size=50)
# Out:
# array([ 0.8395142 ,  0.76127866,  1.37992618,  0.43554926,  1.26849698,
#         1.17506382,  1.97845407,  1.30821119,  1.12641923,  2.0804035 ,
#         0.52688882,  1.96941311,  1.09725973,  1.11354305,  0.39869251,
#         1.33946191,  0.64935086,  1.41703246,  0.94248806,  0.06716408,
#         0.75945309,  1.02194606, -0.0066741 ,  0.50011975,  0.21412171,
#         1.22944692,  0.89204087,  1.5831503 ,  0.3533085 ,  0.88224955,
#         1.04895473,  1.76919095,  1.43784114,  0.78535424,  1.05659918,
#         1.76998582,  0.92479662,  1.19560574,  1.27350335,  1.73112708,
#         1.56400809,  1.4788488 ,  0.92480438,  1.32975909,  1.62742638,
#         1.10818099,  0.56834865,  0.79050159,  1.16593614,  0.87372502])

# %%
np.random.rand(10,20)
# Out:
# array([[0.52217516, 0.77708195, 0.86150466, 0.68409767, 0.61039572,
#         0.28281546, 0.93801735, 0.46816525, 0.33454082, 0.56864599,
#         0.11000048, 0.64188542, 0.9646221 , 0.4856867 , 0.36742775,
#         0.17611497, 0.8250625 , 0.31299303, 0.52887337, 0.69461559],
#        [0.86482663, 0.61117329, 0.17522647, 0.98246956, 0.7451394 ,
#         0.40362659, 0.54180016, 0.8949027 , 0.92556599, 0.29625409,
#         0.6815048 , 0.20396494, 0.28482198, 0.03802345, 0.53334402,
#         0.88788834, 0.66783257, 0.22453755, 0.16109904, 0.44885278],
#        [0.1171375 , 0.45770268, 0.27766721, 0.84812863, 0.55407284,
#         0.04110044, 0.62307962, 0.28634705, 0.34422361, 0.37518573,
#         0.17051677, 0.90767887, 0.49473588, 0.01033807, 0.25384282,
#         0.69212941, 0.06597627, 0.0076085 , 0.53193859, 0.1336865 ],
#        [0.7208582 , 0.64827617, 0.8082466 , 0.04454669, 0.71462682,
#         0.55138688, 0.09427711, 0.21907886, 0.84911466, 0.57691131,
# ...

# %%
np.mean(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 np.mean(axis=1)
#
# TypeError: mean() missing 1 required positional argument: 'a'

# %%
np.vstack([array1,array2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 np.vstack([array1,array2])
#
# NameError: name 'array1' is not defined

# %%
np.zeros(40)
np.ones(40)
np.concatenate([np.zeros,np.ones])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 np.zeros(40)
#       2 np.ones(40)
# ----> 3 np.concatenate([np.zeros,np.ones])
#
# ValueError: zero-dimensional arrays cannot be concatenated
